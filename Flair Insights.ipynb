# %%
# !pip install requests
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.shokubai.co.jp/en/products/detail/nvp/'

# %%
response  = requests.get(url)

# %%
import pandas as pd
tables = pd.read_html(response.content)

# %%
if response.status_code == 200:
  soup = BeautifulSoup(response.content, 'html.parser')
  links = soup.find_all('a')
  for link in links:
    print("Text:", link.text)
  print("URL:", link.get('href'))
else:
  print("falied to retrieve webpage. status code:", response.status_code)
# Out:
# Text:
#
# NIPPON SHOKUBAI CO., LTD.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Text: Company Information
# Text: Company Information TOP
# Text: Creative chemistry
# Text: Message from the President
# Text: Company Profile
# Text: Group Mission Framework / Safety Philosophy
# Text: Management Policies/Plans
# Text: Management/Organization
# Text: Policies
# Text: Business Locations
# Text: Access Map
# Text: History of Nippon Shokubai
# Text: Introductory Videos about Nippon Shokubai
# Text: Products
# Text: R&D
# Text: R&D TOP
# Text: Research and DevelopmentStrategies
# Text: Core Technologiesof Nippon Shokubai
# Text: R&D for the future
# Text: Intellectual Property Activities
# Text: Papers/Presentations
# Text: Research and Development Organization/Locations
# Text: History of Research and Development
# Text:  Investor Relations
# Text: Investor Relations
# Text: Message from the President
# Text: Management Policies/Plans
# Text: Mid-term Management Plan
# ...

# %%
for i in soup.find_all('h2','wp-block-heading'):
  print(i,  "\n",i.text)
# Out:
# <h2 class="wp-block-heading" id="anc01">Basic Information
# </h2>
#  Basic Information
#
# <h2 class="wp-block-heading" id="anc02">Features and Properties
# </h2>
#  Features and Properties

# %%
# !pip install pandas

# %%
df = pd.read_html('https://www.shokubai.co.jp/en/products/detail/nvp/')
df
# Out:
# [                                                   0  \
#  0                                 Chemical Structure
#  1                                   Chemical Formula
#  2                     Appearance and Main Properties
#  3         Chemical Substances Control Act (CSCA) No.
#  4                                             EINECS
#  5                                   Fire Service Act
#  6  Act on the Promotion of Chemical Substance Man...
#  7          Hazardous Materials Database Registration
#  8                                         Stabilizer
#
#                                                     1
#  0                                                NaN
#  1                                             C6H9NO
#  2  Appearance: Transparent liquid Molecular weigh...
#  3                                   (Existing) 5-114
#  4                                          201-800-4
#  5  Hazardous materials, Category IV Class III Pet...
# ...

# %%
print(type(df))
# Out:
# <class 'list'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#">
#   <meta charset="utf-8"/>
#   <meta content="" name="twitter:site"/>
#   <meta content="" name="twitter:creator"/>
#   <meta content="https://www.shokubai.co.jp/ja/images/common/ogp.jpg" name="twitter:image:src"/>
#   <meta content="telephone=no, email=no, address=no" name="format-detection"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.shokubai.co.jp/ja/favicon.ico" rel="shortcut icon"/>
#   <link href="https://www.shokubai.co.jp/ja/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://www.shokubai.co.jp/ja/android-touch-icon.png" rel="icon" sizes="192x192" type="image/png"/>
# ...

# %%
soup.title.text
# Out:
# 'N-Vinylpyrrolidone | Products | NIPPON SHOKUBAI'

# %%
data = [heading.text for heading in headings]
df = pd.DataFrame(data, columns=['Headings'])
df.to_csv('headings_data.csv', index=False)
print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.
